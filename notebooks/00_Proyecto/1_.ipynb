# %% [markdown]
# # Cacharrear con Python

# %% [markdown]
# ## Load dataset

# %%
import seaborn as sns

tabla = sns.load_dataset('mpg')

# %% [markdown]
# Hacer la suma a una columna, no poner dentro de parentesis

# %%
tabla.sum()
# Out:
# mpg                                                        9358.8
# cylinders                                                    2171
# displacement                                              76983.5
# horsepower                                                40952.0
# weight                                                    1182229
# acceleration                                               6196.1
# model_year                                                  30252
# origin          usausausausausausausausausausausausausausajapa...
# name            chevrolet chevelle malibubuick skylark 320plym...
# dtype: object

# %%
tabla.mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
tabla.mpg.sum()
# Out:
# np.float64(9358.8)

# %%
tabla.sum()
# Out:
# mpg                                                        9358.8
# cylinders                                                    2171
# displacement                                              76983.5
# horsepower                                                40952.0
# weight                                                    1182229
# acceleration                                               6196.1
# model_year                                                  30252
# origin          usausausausausausausausausausausausausausajapa...
# name            chevrolet chevelle malibubuick skylark 320plym...
# dtype: object

# %%
tabla.mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
tabla['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %% [markdown]
# ## Dos columnas en el boxplot

# %%
tabla.boxplot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
tabla[].hist(asdf)
plt.show()

# %%
tabla[['mpg', 'weight']].boxplot()
plt.show()

# %%
tabla.boxplot(column=['mpg','weight'])
plt.show()

# %%
tabla.boxplot(column='mpg')
# Out:
# <Axes: >

# %%
tabla[['weight', 'mpg']]
# Out:
#      weight   mpg
# 0      3504  18.0
# 1      3693  15.0
# 2      3436  18.0
# 3      3433  16.0
# 4      3449  17.0
# ..      ...   ...
# 393    2790  27.0
# 394    2130  44.0
# 395    2295  32.0
# 396    2625  28.0
# 397    2720  31.0
#
# [398 rows x 2 columns]

# %%
tabla.sum?
# Out:
# Signature:
# tabla.sum(
#     axis: 'Axis | None' = 0,
#     skipna: 'bool' = True,
#     numeric_only: 'bool' = False,
#     min_count: 'int' = 0,
#     **kwargs,
# )
# Docstring:
# Return the sum of the values over the requested axis.
#
# This is equivalent to the method ``numpy.sum``.
#
# Parameters
# ----------
# axis : {index (0), columns (1)}
#     Axis for the function to be applied on.
#     For `Series` this parameter is unused and defaults to 0.
#
#     .. warning::
#
#         The behavior of DataFrame.sum with ``axis=None`` is deprecated,
#         in a future version this will reduce over both axes and return a scalar
#         To retain the old behavior, pass axis=0 (or do not pass axis).
#
#     .. versionadded:: 2.0.0
#
# skipna : bool, default True
#     Exclude NA/null values when computing the result.
# numeric_only : bool, default False
#     Include only float, int, boolean columns. Not implemented for Series.
#
# min_count : int, default 0
# ...
