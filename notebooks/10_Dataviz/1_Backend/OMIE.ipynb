# %%
from datetime import datetime

# %%
datetime.today().date()
# Out:
# datetime.date(2024, 6, 21)

# %%
DATE = 20240621

# %%
url = f'https://www.omie.es/pt/file-download?parents%5B0%5D=marginalpdbc&filename=marginalpdbc_{DATE}.1'
url
# Out:
# 'https://www.omie.es/pt/file-download?parents%5B0%5D=marginalpdbc&filename=marginalpdbc_20240621.1'

# %%
import pandas as pd

# %%
df = pd.read_csv(url, sep=';', skiprows=1, header=None)

# %%
df.columns = ['year', 'month', 'day', 'hour', 'ES', 'PT', 'X']

# %%
df
# Out:
#     year  month   day  hour      ES      PT   X
# 0   2024    6.0  21.0   1.0  102.72  102.72 NaN
# 1   2024    6.0  21.0   2.0  100.34  100.34 NaN
# 2   2024    6.0  21.0   3.0  102.30  102.30 NaN
# 3   2024    6.0  21.0   4.0  102.30  102.30 NaN
# 4   2024    6.0  21.0   5.0  102.30  102.30 NaN
# 5   2024    6.0  21.0   6.0  102.72  102.72 NaN
# 6   2024    6.0  21.0   7.0  100.00  100.00 NaN
# 7   2024    6.0  21.0   8.0  113.47  113.47 NaN
# 8   2024    6.0  21.0   9.0  114.32  114.32 NaN
# 9   2024    6.0  21.0  10.0  105.00  105.00 NaN
# 10  2024    6.0  21.0  11.0   80.00   80.00 NaN
# 11  2024    6.0  21.0  12.0   60.00   60.00 NaN
# 12  2024    6.0  21.0  13.0   61.34   61.34 NaN
# 13  2024    6.0  21.0  14.0   57.40   57.40 NaN
# 14  2024    6.0  21.0  15.0   55.67   55.10 NaN
# 15  2024    6.0  21.0  16.0   55.67   43.17 NaN
# 16  2024    6.0  21.0  17.0   47.55   40.00 NaN
# 17  2024    6.0  21.0  18.0   49.80   49.80 NaN
# 18  2024    6.0  21.0  19.0   56.75   56.75 NaN
# ...

# %%
df.plot.bar(x='hour', y=['ES', 'PT'])
# Out:
# <Axes: xlabel='hour'>
